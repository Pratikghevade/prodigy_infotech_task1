# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import os

# %%
data=pd.read_csv("IMDB-Movie-Data.csv.xls")

# %%
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df = pd.DataFrame(data)

# %%
Title = df['Title'].head(12)
Rating = df['Rating'].head(12)

# %%
fig = plt.figure(figsize=(10,7))

# %%
# Horizontal bar plot
plt.barh(Title[0:10],Rating[0:10])
# Out:
# <BarContainer object of 10 artists>

# %%
movies_ratings = data[data['Rating'] >= 8.5]
movies_ratings
# Out:
#      Rank                  Title                    Genre  \
# 36     37           Interstellar   Adventure,Drama,Sci-Fi
# 54     55        The Dark Knight       Action,Crime,Drama
# 64     65           The Prestige     Drama,Mystery,Sci-Fi
# 80     81              Inception  Action,Adventure,Sci-Fi
# 96     97          Kimi no na wa  Animation,Drama,Fantasy
# 99    100           The Departed     Crime,Drama,Thriller
# 117   118                 Dangal   Action,Biography,Drama
# 124   125  The Dark Knight Rises          Action,Thriller
# 133   134               Whiplash              Drama,Music
# 249   250       The Intouchables   Biography,Comedy,Drama
# 476   477    The Lives of Others           Drama,Thriller
# 991   992       Taare Zameen Par       Drama,Family,Music
#
#                                            Description  \
# 36   A team of explorers travel through a wormhole ...
# 54   When the menace known as the Joker wreaks havo...
# ...

# %%
highest_rated_movies = movies_ratings['Rating']

# %%
# Plotting histogram
plt.hist(highest_rated_movies, bins=6, color='skyblue', edgecolor='black')
# Adding labels and title
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Highest movies rated by IMdB')
# Out:
# Text(0.5, 1.0, 'Highest movies rated by IMdB')

# %%
movies_2015 = data[data['Year'] == 2015]
movies_2015
# Out:
#      Rank                                       Title  \
# 26     27                     Bahubali: The Beginning
# 50     51  Star Wars: Episode VII - The Force Awakens
# 63     64                        Fifty Shades of Grey
# 67     68                          Mad Max: Fury Road
# 84     85                               Furious Seven
# ..    ...                                         ...
# 967   968                                    The Walk
# 968   969                                     Wrecker
# 976   977                                 Dark Places
# 984   985                                         Max
# 995   996                        Secret in Their Eyes
#
#                          Genre  \
# 26      Action,Adventure,Drama
# 50    Action,Adventure,Fantasy
# 63      Drama,Romance,Thriller
# 67     Action,Adventure,Sci-Fi
# 84       Action,Crime,Thriller
# ..                         ...
# 967  Adventure,Biography,Crime
# 968     Action,Horror,Thriller
# ...

# %%
Title = movies_2015['Title'].head(15)
Revenue = movies_2015['Revenue (Millions)'].head(15)
plt.bar(Title, Revenue)
plt.title('Revenue of few movies released in 2015')
plt.xlabel('Title')
plt.ylabel('Revenue (Millions)')
plt.xticks(rotation=90)
plt.show()

# %%
Title = df['Title'].head(12)
Rating = df['Rating'].head(12)
plt.bar(Title, Rating)
plt.title('verticle Bar Plot of ratings')
plt.xlabel('Title')
plt.ylabel('Rating')
plt.xticks(rotation=90)
plt.show()
